# %%
import pandas as pd
import numpy as np
import sklearn.metrics as m

# %%
wind_csv_path = "../data/cleaned/wind_hourly_cleaned.csv"
wind_hourly = pd.read_csv(wind_csv_path)

# %%
wind_hourly.head()
# Out:
#               datetime  wind_speed
# 0  2024-01-01 00:00:00    0.100000
# 1  2024-01-01 01:00:00    0.283333
# 2  2024-01-01 02:00:00    0.200000
# 3  2024-01-01 03:00:00    0.500000
# 4  2024-01-01 04:00:00    0.966667

# %%
train = wind_hourly.iloc[:-720]
test = wind_hourly.iloc[-720:]

# %%
pred = test.wind_speed.shift(1).dropna()
obs = test.wind_speed[1:]

# %%
mae = m.mean_absolute_error(obs, pred)
rmse = m.mean_squared_error(obs, pred)
mape = np.mean(np.abs((obs - pred)/obs))*100

# %%
 #--- OUTPUT THE RESULTS ---
print("--- Baseline Forecast Error Metrics ---")
print(f"Total Observations: {len(obs):,}")
print("-" * 35)
print(f"Mean Absolute Error (MAE):         {mae:.3f}")
print(f"Root Mean Squared Error (RMSE):    {rmse:.3f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
print("-" * 35)
# Out:
# --- Baseline Forecast Error Metrics ---
# Total Observations: 719
# -----------------------------------
# Mean Absolute Error (MAE):         0.692
# Root Mean Squared Error (RMSE):    1.051
# Mean Absolute Percentage Error (MAPE): inf%
# -----------------------------------
